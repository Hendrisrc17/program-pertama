# %%
# Nilai Statis vs Nilai Inputan User

# %%
panjang = 10
lebar = 70

# %%
luas = panjang * lebar

# %%
print("luas =", luas)
# Out:
# luas = 700

# %%
# Membuat Input Pada Python

# %%
nama = input('masukkan nama anda:')

# %%
print('hendri:', type(hendri))

# %%
# input

# %%
print('kalkulator luas persegi panjang\n')
# Out:
# kalkulator luas persegi panjang

# %%
panjang = input('masukan panjang:')

# %%
lebar = input('masukan lebar:')

# %%
lebar = input('luas=', panjang * lebar)

# %%
print('kalkulator luas persegi panjang\n')
# Out:
# kalkulator luas persegi panjang

# %%
panjang: 3000000000000000000000000

# %%
lebar : 7899876543

# %%
Traceback (most recent call last):
# Out:
#   File "<ipython-input-45-2dbc48277d96>", line 1
#     Traceback (most recent call last):
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
File "02-int.py", line 5, in <module>
# Out:
#   File "<ipython-input-37-b6701cacd913>", line 1
#     File "02-int.py", line 5, in <module>
#          ^
# SyntaxError: invalid syntax

# %%
print('luas =', panjang * lebar)
# Out:
# luas = 700
