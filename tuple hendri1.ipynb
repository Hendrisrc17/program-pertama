# %%
# contoh list and tuple

# %%
# contoh list

# %%
datalist = [1, 2, 3, "zoro"]

# %%
print(datalist)
# Out:
# [1, 2, 3, 'zoro']

# %%
datalist.append("sanji")

# %%
print(datalist)
# Out:
# [1, 2, 3, 'zoro', 'sanji']

# %%
datalist.insert(3, 4)

# %%
datalist.pop(1)
# Out:
# 2

# %%
# contoh tuple

# %%
nametuple = ("hendri", "dimas", "idris", "azwar", "ferdi", "arif")

# %%
print(len(nametuple))
# Out:
# 6

# %%
print(nametuple[1])
# Out:
# dimas

# %%
print(nametuple)
# Out:
# ('hendri', 'dimas', 'idris', 'azwar', 'ferdi', 'arif')

# %%
print('')

# %%
print(nametuple[1])
# Out:
# dimas

# %%
print(nametuple[2])
# Out:
# idris

# %%
print(nametuple[0])
# Out:
# hendri

# %%
print('')

# %%
for a in nametuple:
  print(a)
# Out:
# hendri
# dimas
# idris
# azwar
# ferdi
# arif

# %%
print('')

# %%
print("METODE TUPLE")
# Out:
# METODE TUPLE

# %%
# menghitung berapa indeks yang ada di dalam tuple

# %%
print(nametuple.count("arif"))
# Out:
# 1

# %%
# mencari tau nama yang kalian cari ada di urtan no berapa

# %%
print(nametuple.index("azwar"))
# Out:
# 3

# %%
# catatan tuple

# %%
# 1. tuple ialah metode yang tidak dapat di ubah

# %%
# 2. tuple ialah sifat ordered/secara urut

# %%
# 3. tuple dapat menyimpan lebih dari 1 variabel
