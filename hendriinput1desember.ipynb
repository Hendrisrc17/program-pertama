# %%
if True:
  print('kode program ini akan dieksekusi')
# Out:
# kode program ini akan dieksekusi

# %%
if False:
  print('kode program ini tidak akan dieksekusi')

# %%
print('kode program ini akan selalu dieksekusi')
# Out:
# kode program ini akan selalu dieksekusi

# %%
nilai = 30
print('nilai anda adalah:', nilai, '\n')

if nilai >= 65:
  print('selamat, anda lulus!')

else:
    print('maaf, anda tidak lulus.')
# Out:
# nilai anda adalah: 30
#
# maaf, anda tidak lulus.

# %%
nilai = 100
print('nilai anda adalah:', nilai, '\n')

if nilai >= 65:
  print('selamat, anda lulus!')

else:
    print('maaf, anda tidak lulus.')
# Out:
# nilai anda adalah: 100
#
# selamat, anda lulus!

# %%
nilai = int(input('masukan nilai anda: '))
print('nilai anda adalah:', nilai, '\n')

if nilai >= 65:
  print('selamat, anda lulus!')

else:
    print('maaf, anda tidak lulus.')
# Out:
# masukan nilai anda: 100
# nilai anda adalah: 100
#
# selamat, anda lulus!

# %%
nilai = int(input('masukan nilai anda: '))
if nilai >= 90:
  print('predikat A')
elif nilai >= 80:
  print('predikat B')
elif nilai >= 60:
  print('predikat C')
elif nilai >= 40:
  print('predikat D')

else:
  print('predikat E')
# Out:
# masukan nilai anda: 70
# predikat C

# %%
buah_yang_tersedia = ['jeruk', 'mangga', 'melon']
buah_yang_dicari = input('masukan nama buah dalam huruf kecil')

if (buah_yang_dicari in buah_yang_tersedia):
  print('buah yang anda cari tersedia!')

else:
  print('buah yang anda cari tidak tersedia!')
# Out:
# masukan nama buah dalam huruf kecilanggur
# buah yang anda cari tidak tersedia!

# %%
buah_yang_tersedia = ['jeruk', 'mangga', 'melon']
buah_yang_dicari = input('masukan nama buah dalam huruf kecil')

if (buah_yang_dicari in buah_yang_tersedia):
  print('buah yang anda cari tersedia!')

else:
  print('buah yang anda cari tidak tersedia!')
# Out:
# masukan nama buah dalam huruf kecilmangga
# buah yang anda cari tersedia!

# %%
nilai = int(input('masukan nilai:'))
usia = int(input('masukan usia:'))


if nilai >= 80:
  if(usia < 30):
    print('selamat adek, kamu lulus!')
  else:
    print('selamat kakak, kamu lulus')
else:
  if (usia < 30):
    print('mohon maaf dek, coba lagi yah')
  else:
    print('mohon maaf kak, coba lagi yah')
# Out:
# masukan nilai:80
# masukan usia:30
# selamat kakak, kamu lulus
