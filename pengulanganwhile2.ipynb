# %%
# PERULANGAN WHILE

# %%
while (1+2 == 3):
  print('hello dunia!')

# %%
i = 1

while i <= 5:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
listkota = [
   'Jakarta', 'Surabaya', 'Depok', 'Bekasi', 'Solo',
   'Jogjakarta', 'Semarang', 'Makassar'
]
# bermain index
i = 0
while i < len(listkota):
  print(listkota[i])
  i += 1
# Out:
# Jakarta
# Surabaya
# Depok
# Bekasi
# Solo
# Jogjakarta
# Semarang
# Makassar

# %%
# bermain pop
while listkota:
  print(listkota.pop(0))
# Out:
# Jakarta
# Surabaya
# Depok
# Bekasi
# Solo
# Jogjakarta
# Semarang
# Makassar

# %%
a = int(input('masukan bilangan ganjil lebih dari 50: '))

while a % 2 != 1 or a <= 50:
  a = int(input('salah, masukan lagi:'))
print('benar')
# Out:
# masukan bilangan ganjil lebih dari 50: 1
# salah, masukan lagi:1
# salah, masukan lagi:20
# salah, masukan lagi:50
# salah, masukan lagi:100
# salah, masukan lagi:2
# salah, masukan lagi:3
# salah, masukan lagi:10
# salah, masukan lagi:50
# salah, masukan lagi:52
# salah, masukan lagi:54
# salah, masukan lagi:55
# benar

# %%
listkota = [
    'Jakarta', 'Surabaya', 'Depok', 'Bekasi', 'Solo',
    'Jogjakarta', 'Semarang', 'Makassar'
]

# skip jika i adalah bilangan genap
# dan i lebih dari 0

i = -1

while i < len(listkota):
  i += 1
  if i % 2 == 0 and i > 0:
    print('skip')
    continue
  # tidak dieksekusi ketika continue dipanggil
  print(listkota[i])
# Out:
# Jakarta
# Surabaya
# skip
# Bekasi
# skip
# Jogjakarta
# skip
# Makassar
# skip

# %%
listKota = [
    'Jakarta', 'Surabaya', 'Depok', 'Bekasi', 'Solo',
    'Jogjakarta', 'Semarang', 'Makassar'
]

kotaYangDicari = input('Masukkan nama kota yang dicari: ')
i = 0
while i < len(listKota):
  if listKota[i].lower() == kotaYangDicari.lower():
    print('Ketemu di index' , i)
    break

  print('Bukan', listKota[i])
  i += 1
# Out:
# Masukkan nama kota yang dicari: bekasi
# Bukan Jakarta
# Bukan Surabaya
# Bukan Depok
# Ketemu di index 3

# %%
listKota = [
    'Jakarta', 'Surabaya', 'Depok', 'Bekasi', 'Solo',
    'Jogjakarta', 'Semarang', 'Makassar'
]

kotaYangDicari = input('Masukkan nama kota yang dicari: ')
i = 0
while i < len(listKota):
  if listKota[i].lower() == kotaYangDicari.lower():
    print('Ketemu di index' , i)
    break

  print('Bukan', listKota[i])
  i += 1

else:
  print('maaf, kota yang anda cari tidak ditemukan')
# Out:
# Masukkan nama kota yang dicari: makkasar
# Bukan Jakarta
# Bukan Surabaya
# Bukan Depok
# Bukan Bekasi
# Bukan Solo
# Bukan Jogjakarta
# Bukan Semarang
# Bukan Makassar
# maaf, kota yang anda cari tidak ditemukan
