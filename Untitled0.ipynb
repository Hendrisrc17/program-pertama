# %%
list_kosong = []

# %%
list_buah = ["pisang", "nanas", "melon", "durian"]

# %%
list_angka = [100,200,300,400]

# %%
list_campur = ["pisang", 200,300,400, "melon", True, False]

# %%
print ('list_buah', list_buah)
# Out:
# list_buah ['pisang', 'nanas', 'melon', 'durian']

# %%
print ('list_campur', list_campur)
# Out:
# list_campur ['pisang', 200, 300, 400, 'melon', True, False]

# %%
print ('list_kosong', list_kosong)
# Out:
# list_kosong []

# %%
print ('list_kosong', list_buah)
# Out:
# list_kosong ['pisang', 'nanas', 'melon', 'durian']

# %%
print ('list_campur', list_buah)
# Out:
# list_campur ['pisang', 'nanas', 'melon', 'durian']

# %%
print (list_buah[0])
# Out:
# pisang

# %%
print (list_buah[1])
# Out:
# nanas

# %%
print (list_buah[2])
# Out:
# melon

# %%
print (list_buah[3])
# Out:
# durian

# %%
print (list_buah[-1])
# Out:
# durian

# %%
print (list_buah[1:3])
# Out:
# ['nanas', 'melon']

# %%
print (list_buah[0:3])
# Out:
# ['pisang', 'nanas', 'melon']

# %%
print (list_buah[1:])
# Out:
# ['nanas', 'melon', 'durian']

# %%
print (list_buah)
# Out:
# ['pisang', 'nanas', 'melon', 'durian']

# %%
list_buah[-1] ="mangga"

# %%
print (list_buah)
# Out:
# ['pisang', 'nanas', 'melon', 'mangga']

# %%
list_buah[1:3] = ["Anggur", "Kedondong"]

# %%
print (list_buah)
# Out:
# ['pisang', 'Anggur', 'Kedondong', 'mangga']

# %%
list_buah.append("sirsak")

# %%
print (list_buah)
# Out:
# ['pisang', 'Anggur', 'Kedondong', 'mangga', 'sirsak']

# %%
list_buah.insert(0, "jambu")

# %%
print (list_buah)
# Out:
# ['jambu', 'pisang', 'Anggur', 'Kedondong', 'mangga', 'sirsak']

# %%
list_buah.remove("jambu")

# %%
print (list_buah)
# Out:
# ['pisang', 'Anggur', 'Kedondong', 'mangga', 'sirsak']

# %%
del list_buah[1]

# %%
print (list_buah)
# Out:
# ['pisang', 'Kedondong', 'mangga', 'sirsak']

# %%
angka_yang_terhapus = list_angka.pop()

# %%
print("angka yang terhapus", "list angka.pop()")
# Out:
# angka yang terhapus list angka.pop()

# %%
a = [1, 2, 3]
b = ["a"]
c = [True, "b", False]

# %%
listbaru = a+b+c

# %%
print (listbaru)
# Out:
# [1, 2, 3, 'a', True, 'b', False]

# %%
list_angka.sort()
print(list_angka)
# Out:
# [100, 200, 300]

# %%
list_angka.reverse()
print(list_angka)
# Out:
# [300, 200, 100]
