# %%
# membuat fungsi
def salam():
  print ("hello, ini hendri")

# %%
# pemanggilan fungsi
salam()
salam()
salam()
# Out:
# hello, ini hendri
# hello, ini hendri
# hello, ini hendri

# %%
def salam(ucapan):
  print(ucapan)
salam("Selamat Siang Hendri")
# Out:
# Selamat Siang Hendri

# %%
def luas_segitiga(alas, tinggi):
  luas = (alas * tinggi) / 2
  print ("luas segitiga: %f" % luas)

# %%
luas_segitiga(5, 6)
# Out:
# luas segitiga: 15.000000

# %%
# membuat variabel global
nama = "belajar kode"
versi = "1.0.0"

def help():
  # ini variabel lokal
  nama = "programku"
  versi = "1.0.1"

# %%
def help():
  nama = "programku"
  versi = "1.0.1"

# %%
  print ("nama: %s" % nama)
  print ("versi: %s" % versi)
# Out:
# nama: belajar kode
# versi: 1.0.0

# %%
nama = "hendri"
tanggal_lahir = "17 agustus 2003"
alamat = "keramat"
tempat_lahir = "desa bedengung"
jurusan = "ilmu komputer"
hobi = "tari, dance, voly, olahraga"

print ("nama: %s" % nama)
print ("tanggal_lahir: %s" % tanggal_lahir)
print ("tempat_lahir: %s" % tempat_lahir)
print ("alamat: %s" % alamat)
print ("jurusan: %s" % jurusan)
print ("hobi: %s" % hobi)
# Out:
# nama: hendri
# tanggal_lahir: 17 agustus 2003
# tempat_lahir: desa bedengung
# alamat: keramat
# jurusan: ilmu komputer
# hobi: tari, dance, voly, olahraga

# %%
print ("nama: %s" % nama)
print ("tanggal_lahir: %s" % tanggal_lahir)
print ("tempat_lahir: %s" % tempat_lahir)
print ("alamat: %s" % alamat)
print ("jurusan: %s" % jurusan)
print ("hobi: %s" % hobi)
# Out:
# nama: hendri
# tanggal_lahir: 17 agustus 2003
# tempat_lahir: desa bedengung
# alamat: keramat
# jurusan: ilmu komputer
# hobi: tari, dance, voly, olahraga

# %%
# fungsi untuk menampilkan semua data
def show():
  if len(buku) <= 0:
      print("BELUM ADA DATA")
  else:
      for indeks in range(len(buku)):
        print("[{}]] {}" .format(indeks, buku[indeks]))

# %%
def show():
  if len(buku) <= 0:
      print("BELUM ADA DATA")
  else:
      for indeks in range(len(buku)):
        print("[{}]] {}" .format(indeks, buku[indeks]))

# %%
def insert_data():
  buku_baru = input("judul buku: ")
  buku.append(buku_baru)

# %%
def edit_data():
  show_data()
  indeks = int(input("inputkan ID buku"))
  if indeks > len(buku):
    print("ID salah")
  else:
      judul_baru = input("judul baru: ")
      buku[indeks] = judul_baru

# %%
def delete_data():
  show_data()
  indeks = int(input("inputkan ID buku"))
  if indeks > len(buku):
    print("ID salah")
  else:
      buku.remove(buku[indeks])

# %%
def show_menu():
  print("\n")
  print("---------- MENU ----------")
  print("[1] show data")
  print("[2] insert data")
  print("[3] edit data")
  print("[4] delete data")
  print("[5] exit")

  menu = input("PILIH MENU> ")
  print("\n")

# %%
buku = []
def show_data():
    if len(buku) <= 0:
      print("belum ada data")
    else:
      for indek in range (len(buku)):
        print("[{}]] {}".format(indeks,buku[indeks]))

def insert_data():
    buku_baru = input("judul buku: ")
    buku.append(buku_baru)

def edit_data():
    show_data()
    indeks = int(input("inputkan ida buku"))
    if indeks > len(buku):
        print("id salah")
    else:
        judul_baru = input("judul baru:")
        buku[indeks] = judul_baru

def delete_data():
    show_data()
    indeks = int(input("inputkan ida buku"))
    if indeks > len(buku):
        print("id salah")
    else:
        buku.remove(buku[indeks])

def show_menu():
    print("\n")
    print("----------MENU----------")
    print("[1] show data")
    print("[2] insert data")
    print("[3] edit data")
    print("[4] delete data")
    print("[5] exit")

    menu = input("PILIH MENU")
    print("\n")

    if int(menu) == 1:
        show_data()
    elif int(menu) == 2:
        insert_data()
    elif int(menu) == 3:
        edit_data()
    elif int(menu) == 4:
        delete_data()
    elif int(menu) == 5:
        exit()
    else:
        print("salah pilih!")
if __name__ =="__main__":
      while True:
        show_menu()
# Out:
# ----------MENU----------
# [1] show data
# [2] insert data
# [3] edit data
# [4] delete data
# [5] exit
# PILIH MENU2
#
#
# judul buku: hendri
#
#
# ----------MENU----------
# [1] show data
# [2] insert data
# [3] edit data
# [4] delete data
# [5] exit
